# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import os

# %%
met = pd.read_json('data/ground_truth/MET_database.json')
mini_met = pd.read_json('data/ground_truth/mini_MET_database.json')
truth_test = pd.read_json('data/ground_truth/testset.json')
truth_val = pd.read_json('data/ground_truth/valset.json')

# %%
met
# Out:
#             id              path
# 0           34      MET/34/0.jpg
# 1           37      MET/37/2.jpg
# 2           37      MET/37/0.jpg
# 3           37      MET/37/1.jpg
# 4           38      MET/38/0.jpg
# ...        ...               ...
# 397116  844418  MET/844418/0.jpg
# 397117  844418  MET/844418/1.jpg
# 397118  844418  MET/844418/2.jpg
# 397119  844419  MET/844419/1.jpg
# 397120  844419  MET/844419/0.jpg
#
# [397121 rows x 2 columns]

# %%
ids = met["id"]
count = defaultdict(int)
for img in ids:
    count[img] += 1

# %%
count_df = pd.DataFrame.from_dict(count, orient = 'index')
count_df.columns = ['count']
count_df.sort_values('count', ascending = False, inplace = True)

# %%
count_df.head(50)
# Out:
#         count
# 9674       10
# 248475     10
# 547802     10
# 547772     10
# 547699     10
# 547698     10
# 547696     10
# 55973      10
# 460448     10
# 460455     10
# 547334     10
# 443197     10
# 443199     10
# 155954     10
# 448238     10
# 547051     10
# 546870     10
# 154116     10
# 227892     10
# 101441     10
# 141887     10
# 443071     10
# 443056     10
# 227918     10
# 443025     10
# 437028     10
# 437056     10
# 437274     10
# 437372     10
# 208174     10
# 437466     10
# 437567     10
# 437633     10
# 437654     10
# 460281     10
# 548595     10
# 55727      10
# 548344     10
# 548281     10
# 548265     10
# 548257     10
# 227765     10
# 443020     10
# 443023     10
# 141821     10
# 227931     10
# 549534     10
# 127676     10
# 546051     10
# 448213     10

# %%
count_df.tail(50)
# Out:
#         count
# 379298      1
# 379299      1
# 379300      1
# 379301      1
# 379302      1
# 379303      1
# 379305      1
# 379312      1
# 379306      1
# 379307      1
# 379308      1
# 379309      1
# 379310      1
# 379311      1
# 379333      1
# 379334      1
# 379335      1
# 379361      1
# 379354      1
# 379356      1
# 379357      1
# 379358      1
# 379359      1
# 379360      1
# 379362      1
# 379336      1
# 379363      1
# 379364      1
# 175595      1
# 379366      1
# 379367      1
# 379368      1
# 379353      1
# 379352      1
# 379351      1
# 379350      1
# 379349      1
# 379348      1
# 379347      1
# 379346      1
# 379345      1
# 379344      1
# 379343      1
# 379342      1
# 379341      1
# 379340      1
# 379339      1
# 379338      1
# 379337      1
# 34          1

# %%
count_df.describe()
# Out:
#                count
# count  224408.000000
# mean        1.769638
# std         1.504371
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        10.000000

# %%
# fig, ax = plt.subplots()
# ax = sns.barplot(x = count_df.index, y = count_df['count'], ax = ax)
sns.countplot(x = 'id',
              data = met,
              order = met['id'].value_counts().iloc[:50000].index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 6>()
#       1 # fig, ax = plt.subplots()
#       2 # ax = sns.barplot(x = count_df.index, y = count_df['count'], ax = ax)
#       3 sns.countplot(x = 'id',
#       4               data = met,
#       5               order = met['id'].value_counts().iloc[:50000].index)
# ----> 6 plt.show()
#
# File ~/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
# ...

# %%
mini_met
# Out:
#            id              path
# 0          52      MET/52/0.jpg
# 1          63      MET/63/0.jpg
# 2         126     MET/126/0.jpg
# 3         130     MET/130/0.jpg
# 4         134     MET/134/5.jpg
# ...       ...               ...
# 38302  841274  MET/841274/0.jpg
# 38303  841281  MET/841281/0.jpg
# 38304  841283  MET/841283/4.jpg
# 38305  841284  MET/841284/0.jpg
# 38306  841587  MET/841587/0.jpg
#
# [38307 rows x 2 columns]

# %%
ids = mini_met["id"]
count = defaultdict(int)
for img in ids:
    count[img] += 1

# %%
count_df = pd.DataFrame.from_dict(count, orient='index')
count_df.columns = ['count']
count_df.sort_values('count', ascending = False, inplace = True)

# %%
count_df.head(50)
# Out:
#         count
# 549534     10
# 24953      10
# 45417      10
# 3411       10
# 40067      10
# 468215     10
# 464607     10
# 464596     10
# 57773      10
# 39918      10
# 238971     10
# 472312     10
# 455250     10
# 7565       10
# 472386     10
# 466664     10
# 192717     10
# 11417      10
# 543882     10
# 22634      10
# 544211     10
# 464455     10
# 446990     10
# 470599     10
# 24671      10
# 453164     10
# 444717     10
# 40508      10
# 23944      10
# 463717     10
# 471294     10
# 451909     10
# 209314     10
# 451802     10
# 22908      10
# 453385     10
# 444523     10
# 22871      10
# 446986     10
# 24857      10
# 320053     10
# 544887     10
# 547802     10
# 236643     10
# 437372     10
# 226696     10
# 474429     10
# 4511       10
# 464371     10
# 206321     10

# %%
count_df.tail(50)
# Out:
#         count
# 219910      1
# 219909      1
# 219895      1
# 219890      1
# 219874      1
# 219861      1
# 219846      1
# 219836      1
# 219828      1
# 219821      1
# 219792      1
# 219791      1
# 219777      1
# 219763      1
# 219762      1
# 219757      1
# 219753      1
# 219730      1
# 219717      1
# 220019      1
# 220020      1
# 220036      1
# 220254      1
# 220652      1
# 220634      1
# 220632      1
# 220604      1
# 220544      1
# 220420      1
# 220408      1
# 220372      1
# 220341      1
# 220315      1
# 220276      1
# 220271      1
# 220249      1
# 220055      1
# 220236      1
# 220191      1
# 220184      1
# 220183      1
# 220162      1
# 220161      1
# 220143      1
# 220140      1
# 220134      1
# 220100      1
# 220092      1
# 220060      1
# 841587      1

# %%
count_df.describe()
# Out:
#               count
# count  33501.000000
# mean       1.143458
# std        0.649421
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       10.000000

# %%
# fig, ax = plt.subplots()
# ax = sns.barplot(x = count_df.index, y = count_df['count'], ax = ax)
sns.countplot(x = 'id',
              data = mini_met,
              order = mini_met['id'].value_counts().iloc[:10000].index)
plt.show()

# %%
truth_test
# Out:
#          MET_id                         path   photographer  \
# 0      472849.0    test_met/9d2015655fed.jpg  Guangxing Han
# 1      631985.0    test_met/59117d5af04c.jpg  Guangxing Han
# 2        4511.0    test_met/0201fff84b42.jpg  Guangxing Han
# 3       42124.0    test_met/618e48ddb9db.jpg  Guangxing Han
# 4      206698.0    test_met/bf6a4af8198b.jpg  Guangxing Han
# ...         ...                          ...            ...
# 19314       NaN  test_other/d72d2fa81029.jpg            NaN
# 19315       NaN  test_other/774cbb34837e.jpg            NaN
# 19316       NaN  test_other/398a3cc82483.jpg            NaN
# 19317       NaN  test_other/23296b18c4dd.jpg            NaN
# 19318       NaN  test_noart/ac4427950f84.jpg            NaN
#
#                                                      url  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# ...

# %%
truth_val
# Out:
#         MET_id                         path  photographer  \
# 0      42554.0    test_met/6f2cd0c0c07b.jpg  60258967@N00
# 1      62216.0    test_met/780b4e052f71.jpg  60258967@N00
# 2     670963.0    test_met/2f83dc79c7a1.jpg  60258967@N00
# 3     464332.0    test_met/3fa0ebcc40a3.jpg  60258967@N00
# 4     210829.0    test_met/1afdf55b5b2c.jpg  60258967@N00
# ...        ...                          ...           ...
# 2160       NaN  test_other/d8e51563ffe3.jpg           NaN
# 2161       NaN  test_noart/74dcde3c9a32.jpg           NaN
# 2162       NaN  test_noart/ad4c96671aa5.jpg           NaN
# 2163       NaN  test_noart/184086b50958.jpg           NaN
# 2164       NaN  test_noart/cd8f5e65b658.jpg           NaN
#
#                                                     url          category
# 0     https://live.staticflickr.com/4002/34910120283...               NaN
# 1     https://live.staticflickr.com/4217/35680553936...               NaN
# ...

# %%
from os import listdir
from PIL import Image as PImage

def loadImages(path):
    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        loadedImages.append(img)
    return loadedImages

path = "data/test_met/"

imgs = loadImages(path)

fig = plt.gcf()
for img in imgs[:10]:
    plt.imshow(img)
    plt.show()
